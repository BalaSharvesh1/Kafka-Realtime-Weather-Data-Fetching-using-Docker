# %%
# %pip install psycopg2
# Out:
# Collecting psycopg2
#   Downloading psycopg2-2.9.11-cp314-cp314-win_amd64.whl.metadata (5.1 kB)
# Downloading psycopg2-2.9.11-cp314-cp314-win_amd64.whl (2.8 MB)
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ------- -------------------------------- 0.5/2.8 MB 2.3 MB/s eta 0:00:01
#    -------------- ------------------------- 1.0/2.8 MB 2.7 MB/s eta 0:00:01
#    -------------------------- ------------- 1.8/2.8 MB 3.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 2.1/2.8 MB 2.9 MB/s eta 0:00:01
#    ------------------------------------- -- 2.6/2.8 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 2.4 MB/s  0:00:01
# Installing collected packages: psycopg2
# Successfully installed psycopg2-2.9.11
# Note: you may need to restart the kernel to use updated packages.

# %%
import psycopg2
import pandas as pd
from sklearn.linear_model import LinearRegression
import warnings
warnings.filterwarnings('ignore')
conn = psycopg2.connect(
    dbname="nrdb",
    user="user",
    password="password",
    host="127.0.0.1",
    port="5432"
)


query = "SELECT * FROM weather_data;"
df = pd.read_sql(query, conn)

conn.close()
df.head()
# Out:
#    id       city  temperature condition                  timestamp
# 0   1  Nagercoil         28.1      Mist 2026-01-21 15:37:52.419239
# 1   2  Nagercoil         28.1      Mist 2026-01-21 15:37:57.562938
# 2   3  Nagercoil         28.1      Mist 2026-01-21 15:38:08.773523
# 3   4  Nagercoil         28.1      Mist 2026-01-21 15:38:19.706856
# 4   5  Nagercoil         28.1      Mist 2026-01-21 15:38:31.129272

# %%
df.columns
# Out:
# Index(['id', 'city', 'temperature', 'condition', 'timestamp'], dtype='object')

# %%
len(df)
# Out:
# 215

# %%
#download the dataframe as csv
df.to_csv('weather_data.csv', index=False)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['condition'] = le.fit_transform(df['condition'])

# %%
x = df[['temperature']]
y = df['condition']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(max_depth=5)
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=5)

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 1.0

# %%
from sklearn.metrics import classification_report
cl = classification_report(y_test, y_pred)
print(cl)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        56
#            1       1.00      1.00      1.00         7
#
#     accuracy                           1.00        63
#    macro avg       1.00      1.00      1.00        63
# weighted avg       1.00      1.00      1.00        63

# %%
# %pip install seaborn matplotlib
# Out:
# Requirement already satisfied: seaborn in d:\programing codes\kafka\.venv\lib\site-packages (0.13.2)
# Requirement already satisfied: matplotlib in d:\programing codes\kafka\.venv\lib\site-packages (3.10.8)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in d:\programing codes\kafka\.venv\lib\site-packages (from seaborn) (2.4.1)
# Requirement already satisfied: pandas>=1.2 in d:\programing codes\kafka\.venv\lib\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: contourpy>=1.0.1 in d:\programing codes\kafka\.venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in d:\programing codes\kafka\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\programing codes\kafka\.venv\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\programing codes\kafka\.venv\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in d:\programing codes\kafka\.venv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in d:\programing codes\kafka\.venv\lib\site-packages (from matplotlib) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in d:\programing codes\kafka\.venv\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in d:\programing codes\kafka\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\programing codes\kafka\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\programing codes\kafka\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: six>=1.5 in d:\programing codes\kafka\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=le.classes_, yticklabels=le.classes_)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
